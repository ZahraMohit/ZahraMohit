# %% [markdown]
# <a href="https://colab.research.google.com/github/ZahraMohit/ZahraMohit/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout , Flatten
from tensorflow.keras.optimizers import Adam

# %%
fashion_mnist = keras.datasets.fashion_mnist
(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()
# Out:
# ...
# 4422102/4422102 [==============================] - 0s 0us/step

# %%
len(train_images)
# Out:
# 60000

# %%
len(test_images)
# Out:
# 10000

# %%
import matplotlib.pyplot as plt

plt.imshow(train_images[9])

# %%
plt.imshow(train_images[99])

# %%
plt.imshow(train_images[9009])

# %%
train_images, test_images = train_images / 255.0, test_images / 255.0

# %%
model = Sequential([
  Flatten(input_shape=(28, 28)),
  Dense(128, activation='relu'),
  Dropout(0.2),
  Dense(10)
])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 128)               100480
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 10)                1290
#
# ...
# Total params: 101770 (397.54 KB)
# Trainable params: 101770 (397.54 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(optimizer='adam',
              loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.fit(train_images, train_labels,batch_size=32, epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3179 - accuracy: 0.8831
# Epoch 2/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.3074 - accuracy: 0.8853
# Epoch 3/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2986 - accuracy: 0.8898
# Epoch 4/10
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.2879 - accuracy: 0.8919
# Epoch 5/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2819 - accuracy: 0.8942
# Epoch 6/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2754 - accuracy: 0.8975
# Epoch 7/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2707 - accuracy: 0.8974
# Epoch 8/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2652 - accuracy: 0.9002
# Epoch 9/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2595 - accuracy: 0.9018
# Epoch 10/10
# ...
